# %% [markdown]
# You do have not to import any third-party modules like NumPy, pandas, and others. Just import `WeatherTrends` object from my module which is named as web. By using this class, you can make plots of not one, not two but any cities which are defined in the city list CSV file!

# %% [markdown]
# For using this module, you have to import my tool like this:

# %%
from web import WeatherTrends

# %% [markdown]
# Create object with any name (e.g tool):

# %%
# note: this object does not take any arguments for its initalization
tool = WeatherTrends()

# %% [markdown]
# For making plots, you should call `make_plot` method and give any city name as a function argument:

# %%
# note: city_name is must be as string
tool.make_plot('Moscow')
# Out:
# <module 'matplotlib.pyplot' from 'c:\\users\\abduaziz\\appdata\\local\\programs\\python\\python38-32\\lib\\site-packages\\matplotlib\\pyplot.py'>
